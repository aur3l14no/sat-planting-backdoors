# %%
import time

from pysat.formula import CNF
from pysat.process import Processor
from pysat.solvers import Solver

# %%
cnf = CNF(from_file='cnfs/april-final/0.cnf')
with open('cnfs/april-final/0.backdoor') as f:
    lines = f.readlines()
    backdoor_dnfs = [[int(l) for l in line.split()] for line in lines]

# %%
backdoor_dnfs[:10]
# Out:
# [[-380, -764, -121, 327, 681, -308, -269, -268, -105, -649],
#  [454, 518, 681, -54, 268, 211, -129, -105, -801],
#  [675, -921, 86, -681, 489, -388, -7, 926],
#  [-736, 675, 489, 695, 86, -681, 406, 921, -7],
#  [-512, -895, -159, -489, 878, 338, 114, -396, -681, -5],
#  [-863, 993, -634, 714, 748, -338, -785, -489, 88, -681],
#  [-926, 675, -921, -792, 489, 86, -681, -104, -7, 510],
#  [454, 681, -501, 268, 302, -177, 211, -105, -518, 959],
#  [-326, 681, -918, 268, -15, -235, -105, -296, -454],
#  [-926, -121, -25, 681, -306, -105, -269, -268, 308, -489]]

# %%
default_kwargs = {
    'rounds': 1,
    'block': False,
    'cover': False,
    'condition': False,
    'decompose': False,
    'elim': False,
    'probe': False,
    'probehbr': False,
    'subsume': False,
    'vivify': False
}

# %%
with Solver(name='g4', bootstrap_with=cnf, use_timer=True) as solver:
    solver.solve()
    print(solver.accum_stats())
    print(solver.time())


# check validity of backdoor
with Solver(name='g4', use_timer=True) as solver:
    for backdoor in backdoor_dnfs:
        solver.add_clause([-l for l in backdoor])
    assert(solver.solve() == False)
    print('Validity checked in:', solver.time())

times = []
stats = []
with Solver(name='g4', bootstrap_with=cnf, use_timer=True) as solver:
    for backdoor in backdoor_dnfs:
        assert(solver.solve(assumptions=backdoor) == False)
        times.append(solver.time())
        stats.append(solver.accum_stats())
print('Max time:', max(times))
print('Mean time:', sum(times) / len(times))
# Out:
# {'restarts': 14, 'conflicts': 8970, 'decisions': 44866, 'propagations': 67141}
# 4.005186203000001
# Validity checked in: 0.004970557999996572
# Max time: 0.064132579999999
# Mean time: 0.0018662992979891144

# %%
stats
# Out:
# [{'restarts': 1, 'conflicts': 2, 'decisions': 0, 'propagations': 14},
#  {'restarts': 2, 'conflicts': 4, 'decisions': 0, 'propagations': 26},
#  {'restarts': 3, 'conflicts': 5, 'decisions': 0, 'propagations': 35},
#  {'restarts': 4, 'conflicts': 6, 'decisions': 0, 'propagations': 45},
#  {'restarts': 5, 'conflicts': 8, 'decisions': 0, 'propagations': 57},
#  {'restarts': 6, 'conflicts': 9, 'decisions': 0, 'propagations': 68},
#  {'restarts': 7, 'conflicts': 11, 'decisions': 0, 'propagations': 80},
#  {'restarts': 8, 'conflicts': 13, 'decisions': 0, 'propagations': 92},
#  {'restarts': 9, 'conflicts': 14, 'decisions': 0, 'propagations': 102},
#  {'restarts': 10, 'conflicts': 16, 'decisions': 0, 'propagations': 114},
#  {'restarts': 11, 'conflicts': 17, 'decisions': 0, 'propagations': 124},
#  {'restarts': 12, 'conflicts': 19, 'decisions': 0, 'propagations': 135},
#  {'restarts': 13, 'conflicts': 20, 'decisions': 0, 'propagations': 145},
#  {'restarts': 14, 'conflicts': 21, 'decisions': 0, 'propagations': 154},
#  {'restarts': 15, 'conflicts': 22, 'decisions': 0, 'propagations': 165},
#  {'restarts': 16, 'conflicts': 24, 'decisions': 0, 'propagations': 177},
#  {'restarts': 17, 'conflicts': 26, 'decisions': 0, 'propagations': 189},
#  {'restarts': 18, 'conflicts': 27, 'decisions': 0, 'propagations': 199},
#  {'restarts': 19, 'conflicts': 28, 'decisions': 0, 'propagations': 209},
#  {'restarts': 20, 'conflicts': 29, 'decisions': 0, 'propagations': 220},
#  {'restarts': 21, 'conflicts': 31, 'decisions': 0, 'propagations': 231},
#  {'restarts': 22, 'conflicts': 32, 'decisions': 0, 'propagations': 241},
#  {'restarts': 23, 'conflicts': 33, 'decisions': 0, 'propagations': 251},
#  {'restarts': 24, 'conflicts': 34, 'decisions': 0, 'propagations': 261},
#  {'restarts': 25, 'conflicts': 36, 'decisions': 0, 'propagations': 273},
#  {'restarts': 26, 'conflicts': 37, 'decisions': 0, 'propagations': 283},
#  {'restarts': 27, 'conflicts': 38, 'decisions': 0, 'propagations': 293},
#  {'restarts': 28, 'conflicts': 40, 'decisions': 0, 'propagations': 304},
#  {'restarts': 29, 'conflicts': 41, 'decisions': 0, 'propagations': 316},
#  {'restarts': 30, 'conflicts': 43, 'decisions': 0, 'propagations': 328},
#  {'restarts': 31, 'conflicts': 44, 'decisions': 0, 'propagations': 339},
#  {'restarts': 32, 'conflicts': 45, 'decisions': 0, 'propagations': 350},
#  {'restarts': 33, 'conflicts': 47, 'decisions': 0, 'propagations': 359},
#  {'restarts': 34, 'conflicts': 50, 'decisions': 0, 'propagations': 374},
#  {'restarts': 35, 'conflicts': 52, 'decisions': 0, 'propagations': 386},
#  {'restarts': 36, 'conflicts': 53, 'decisions': 0, 'propagations': 398},
#  {'restarts': 37, 'conflicts': 54, 'decisions': 0, 'propagations': 408},
#  {'restarts': 38, 'conflicts': 56, 'decisions': 0, 'propagations': 421},
#  {'restarts': 39, 'conflicts': 57, 'decisions': 0, 'propagations': 429},
#  {'restarts': 40, 'conflicts': 58, 'decisions': 0, 'propagations': 439},
#  {'restarts': 41, 'conflicts': 59, 'decisions': 0, 'propagations': 449},
#  {'restarts': 42, 'conflicts': 60, 'decisions': 0, 'propagations': 459},
#  {'restarts': 43, 'conflicts': 62, 'decisions': 0, 'propagations': 470},
#  {'restarts': 44, 'conflicts': 63, 'decisions': 0, 'propagations': 480},
#  {'restarts': 45, 'conflicts': 64, 'decisions': 0, 'propagations': 490},
#  {'restarts': 46, 'conflicts': 65, 'decisions': 0, 'propagations': 500},
#  {'restarts': 47, 'conflicts': 67, 'decisions': 0, 'propagations': 511},
#  {'restarts': 48, 'conflicts': 68, 'decisions': 0, 'propagations': 519},
#  {'restarts': 49, 'conflicts': 70, 'decisions': 0, 'propagations': 532},
#  {'restarts': 50, 'conflicts': 71, 'decisions': 0, 'propagations': 542},
#  {'restarts': 51, 'conflicts': 72, 'decisions': 0, 'propagations': 553},
#  {'restarts': 52, 'conflicts': 73, 'decisions': 0, 'propagations': 562},
#  {'restarts': 53, 'conflicts': 74, 'decisions': 0, 'propagations': 573},
#  {'restarts': 54, 'conflicts': 76, 'decisions': 0, 'propagations': 587},
#  {'restarts': 55, 'conflicts': 77, 'decisions': 0, 'propagations': 598},
#  {'restarts': 56, 'conflicts': 78, 'decisions': 0, 'propagations': 608},
#  {'restarts': 57, 'conflicts': 79, 'decisions': 0, 'propagations': 618},
#  {'restarts': 58, 'conflicts': 80, 'decisions': 0, 'propagations': 629},
#  {'restarts': 59, 'conflicts': 81, 'decisions': 0, 'propagations': 640},
#  {'restarts': 60, 'conflicts': 82, 'decisions': 0, 'propagations': 649},
#  {'restarts': 61, 'conflicts': 83, 'decisions': 0, 'propagations': 659},
#  {'restarts': 62, 'conflicts': 84, 'decisions': 0, 'propagations': 670},
#  {'restarts': 63, 'conflicts': 86, 'decisions': 0, 'propagations': 680},
#  {'restarts': 64, 'conflicts': 87, 'decisions': 0, 'propagations': 689},
#  {'restarts': 65, 'conflicts': 89, 'decisions': 0, 'propagations': 701},
#  {'restarts': 66, 'conflicts': 90, 'decisions': 0, 'propagations': 711},
#  {'restarts': 67, 'conflicts': 93, 'decisions': 0, 'propagations': 723},
#  {'restarts': 68, 'conflicts': 94, 'decisions': 0, 'propagations': 732},
#  {'restarts': 69, 'conflicts': 95, 'decisions': 0, 'propagations': 742},
#  {'restarts': 70, 'conflicts': 96, 'decisions': 0, 'propagations': 753},
#  {'restarts': 71, 'conflicts': 97, 'decisions': 0, 'propagations': 764},
#  {'restarts': 72, 'conflicts': 98, 'decisions': 0, 'propagations': 773},
#  {'restarts': 73, 'conflicts': 100, 'decisions': 0, 'propagations': 785},
#  {'restarts': 74, 'conflicts': 101, 'decisions': 0, 'propagations': 796},
#  {'restarts': 75, 'conflicts': 102, 'decisions': 0, 'propagations': 809},
#  {'restarts': 76, 'conflicts': 103, 'decisions': 0, 'propagations': 819},
#  {'restarts': 77, 'conflicts': 104, 'decisions': 0, 'propagations': 830},
#  {'restarts': 78, 'conflicts': 105, 'decisions': 0, 'propagations': 840},
#  {'restarts': 79, 'conflicts': 106, 'decisions': 0, 'propagations': 853},
#  {'restarts': 80, 'conflicts': 107, 'decisions': 0, 'propagations': 862},
#  {'restarts': 81, 'conflicts': 109, 'decisions': 0, 'propagations': 874},
#  {'restarts': 82, 'conflicts': 111, 'decisions': 0, 'propagations': 885},
#  {'restarts': 83, 'conflicts': 112, 'decisions': 0, 'propagations': 896},
#  {'restarts': 84, 'conflicts': 113, 'decisions': 0, 'propagations': 907},
#  {'restarts': 85, 'conflicts': 114, 'decisions': 0, 'propagations': 917},
#  {'restarts': 86, 'conflicts': 115, 'decisions': 0, 'propagations': 928},
#  {'restarts': 87, 'conflicts': 116, 'decisions': 0, 'propagations': 939},
#  {'restarts': 88, 'conflicts': 117, 'decisions': 0, 'propagations': 948},
#  {'restarts': 89, 'conflicts': 118, 'decisions': 0, 'propagations': 957},
#  {'restarts': 90, 'conflicts': 119, 'decisions': 0, 'propagations': 968},
#  {'restarts': 91, 'conflicts': 120, 'decisions': 0, 'propagations': 978},
#  {'restarts': 92, 'conflicts': 122, 'decisions': 0, 'propagations': 991},
#  {'restarts': 93, 'conflicts': 124, 'decisions': 0, 'propagations': 1002},
#  {'restarts': 94, 'conflicts': 125, 'decisions': 0, 'propagations': 1010},
#  {'restarts': 95, 'conflicts': 126, 'decisions': 0, 'propagations': 1020},
#  {'restarts': 96, 'conflicts': 127, 'decisions': 0, 'propagations': 1030},
#  {'restarts': 97, 'conflicts': 128, 'decisions': 0, 'propagations': 1039},
#  {'restarts': 98, 'conflicts': 129, 'decisions': 0, 'propagations': 1048},
#  {'restarts': 99, 'conflicts': 130, 'decisions': 0, 'propagations': 1057},
#  {'restarts': 100, 'conflicts': 132, 'decisions': 0, 'propagations': 1069},
#  {'restarts': 101, 'conflicts': 132, 'decisions': 0, 'propagations': 1077},
#  {'restarts': 102, 'conflicts': 133, 'decisions': 0, 'propagations': 1088},
#  {'restarts': 103, 'conflicts': 134, 'decisions': 0, 'propagations': 1098},
#  {'restarts': 104, 'conflicts': 135, 'decisions': 0, 'propagations': 1109},
#  {'restarts': 105, 'conflicts': 136, 'decisions': 0, 'propagations': 1120},
#  {'restarts': 106, 'conflicts': 136, 'decisions': 0, 'propagations': 1130},
#  {'restarts': 107, 'conflicts': 136, 'decisions': 0, 'propagations': 1139},
#  {'restarts': 108, 'conflicts': 138, 'decisions': 0, 'propagations': 1149},
#  {'restarts': 109, 'conflicts': 140, 'decisions': 0, 'propagations': 1160},
#  {'restarts': 110, 'conflicts': 141, 'decisions': 0, 'propagations': 1172},
#  {'restarts': 111, 'conflicts': 143, 'decisions': 0, 'propagations': 1184},
#  {'restarts': 112, 'conflicts': 144, 'decisions': 0, 'propagations': 1194},
#  {'restarts': 113, 'conflicts': 145, 'decisions': 0, 'propagations': 1204},
#  {'restarts': 114, 'conflicts': 147, 'decisions': 0, 'propagations': 1216},
#  {'restarts': 115, 'conflicts': 148, 'decisions': 0, 'propagations': 1225},
#  {'restarts': 116, 'conflicts': 149, 'decisions': 0, 'propagations': 1234},
#  {'restarts': 117, 'conflicts': 149, 'decisions': 0, 'propagations': 1242},
#  {'restarts': 118, 'conflicts': 152, 'decisions': 0, 'propagations': 1256},
#  {'restarts': 119, 'conflicts': 153, 'decisions': 0, 'propagations': 1266},
#  {'restarts': 120, 'conflicts': 154, 'decisions': 0, 'propagations': 1276},
#  {'restarts': 121, 'conflicts': 156, 'decisions': 0, 'propagations': 1288},
#  {'restarts': 122, 'conflicts': 157, 'decisions': 0, 'propagations': 1298},
#  {'restarts': 123, 'conflicts': 159, 'decisions': 0, 'propagations': 1309},
#  {'restarts': 124, 'conflicts': 160, 'decisions': 0, 'propagations': 1320},
#  {'restarts': 125, 'conflicts': 161, 'decisions': 0, 'propagations': 1331},
#  {'restarts': 126, 'conflicts': 162, 'decisions': 0, 'propagations': 1341},
#  {'restarts': 127, 'conflicts': 164, 'decisions': 0, 'propagations': 1352},
#  {'restarts': 128, 'conflicts': 165, 'decisions': 0, 'propagations': 1364},
#  {'restarts': 129, 'conflicts': 166, 'decisions': 0, 'propagations': 1374},
#  {'restarts': 130, 'conflicts': 167, 'decisions': 0, 'propagations': 1384},
#  {'restarts': 131, 'conflicts': 168, 'decisions': 0, 'propagations': 1396},
#  {'restarts': 132, 'conflicts': 169, 'decisions': 0, 'propagations': 1405},
#  {'restarts': 133, 'conflicts': 170, 'decisions': 0, 'propagations': 1415},
#  {'restarts': 134, 'conflicts': 171, 'decisions': 0, 'propagations': 1425},
#  {'restarts': 135, 'conflicts': 172, 'decisions': 0, 'propagations': 1436},
#  {'restarts': 136, 'conflicts': 173, 'decisions': 0, 'propagations': 1445},
#  {'restarts': 137, 'conflicts': 175, 'decisions': 0, 'propagations': 1456},
#  {'restarts': 138, 'conflicts': 176, 'decisions': 0, 'propagations': 1467},
#  {'restarts': 139, 'conflicts': 177, 'decisions': 0, 'propagations': 1477},
#  {'restarts': 140, 'conflicts': 178, 'decisions': 0, 'propagations': 1487},
#  {'restarts': 141, 'conflicts': 179, 'decisions': 0, 'propagations': 1497},
#  {'restarts': 142, 'conflicts': 180, 'decisions': 0, 'propagations': 1507},
#  {'restarts': 143, 'conflicts': 181, 'decisions': 0, 'propagations': 1517},
#  {'restarts': 144, 'conflicts': 182, 'decisions': 0, 'propagations': 1529},
#  {'restarts': 145, 'conflicts': 183, 'decisions': 0, 'propagations': 1539},
#  {'restarts': 146, 'conflicts': 184, 'decisions': 0, 'propagations': 1548},
#  {'restarts': 147, 'conflicts': 185, 'decisions': 0, 'propagations': 1557},
#  {'restarts': 148, 'conflicts': 186, 'decisions': 0, 'propagations': 1567},
#  {'restarts': 149, 'conflicts': 187, 'decisions': 0, 'propagations': 1577},
#  {'restarts': 150, 'conflicts': 188, 'decisions': 0, 'propagations': 1588},
#  {'restarts': 151, 'conflicts': 188, 'decisions': 0, 'propagations': 1598},
#  {'restarts': 152, 'conflicts': 189, 'decisions': 0, 'propagations': 1609},
#  {'restarts': 153, 'conflicts': 190, 'decisions': 0, 'propagations': 1618},
#  {'restarts': 154, 'conflicts': 191, 'decisions': 0, 'propagations': 1629},
#  {'restarts': 155, 'conflicts': 193, 'decisions': 0, 'propagations': 1639},
#  {'restarts': 156, 'conflicts': 194, 'decisions': 0, 'propagations': 1651},
#  {'restarts': 157, 'conflicts': 196, 'decisions': 0, 'propagations': 1664},
#  {'restarts': 158, 'conflicts': 198, 'decisions': 0, 'propagations': 1676},
#  {'restarts': 159, 'conflicts': 200, 'decisions': 0, 'propagations': 1687},
#  {'restarts': 160, 'conflicts': 201, 'decisions': 0, 'propagations': 1696},
#  {'restarts': 161, 'conflicts': 202, 'decisions': 0, 'propagations': 1707},
#  {'restarts': 162, 'conflicts': 203, 'decisions': 0, 'propagations': 1716},
#  {'restarts': 163, 'conflicts': 204, 'decisions': 0, 'propagations': 1727},
#  {'restarts': 164, 'conflicts': 206, 'decisions': 0, 'propagations': 1738},
#  {'restarts': 165, 'conflicts': 208, 'decisions': 0, 'propagations': 1750},
#  {'restarts': 166, 'conflicts': 209, 'decisions': 0, 'propagations': 1760},
#  {'restarts': 167, 'conflicts': 210, 'decisions': 0, 'propagations': 1769},
#  {'restarts': 168, 'conflicts': 211, 'decisions': 0, 'propagations': 1781},
#  {'restarts': 169, 'conflicts': 212, 'decisions': 0, 'propagations': 1791},
#  {'restarts': 170, 'conflicts': 214, 'decisions': 0, 'propagations': 1803},
#  {'restarts': 171, 'conflicts': 216, 'decisions': 0, 'propagations': 1815},
#  {'restarts': 172, 'conflicts': 217, 'decisions': 0, 'propagations': 1825},
#  {'restarts': 173, 'conflicts': 218, 'decisions': 0, 'propagations': 1834},
#  {'restarts': 174, 'conflicts': 219, 'decisions': 0, 'propagations': 1844},
#  {'restarts': 175, 'conflicts': 220, 'decisions': 0, 'propagations': 1854},
#  {'restarts': 176, 'conflicts': 220, 'decisions': 0, 'propagations': 1862},
#  {'restarts': 177, 'conflicts': 221, 'decisions': 0, 'propagations': 1873},
#  {'restarts': 178, 'conflicts': 223, 'decisions': 0, 'propagations': 1885},
#  {'restarts': 179, 'conflicts': 224, 'decisions': 0, 'propagations': 1896},
#  {'restarts': 180, 'conflicts': 225, 'decisions': 0, 'propagations': 1905},
#  {'restarts': 181, 'conflicts': 225, 'decisions': 0, 'propagations': 1914},
#  {'restarts': 182, 'conflicts': 226, 'decisions': 0, 'propagations': 1925},
#  {'restarts': 183, 'conflicts': 227, 'decisions': 0, 'propagations': 1935},
#  {'restarts': 184, 'conflicts': 229, 'decisions': 0, 'propagations': 1947},
#  {'restarts': 185, 'conflicts': 232, 'decisions': 0, 'propagations': 1960},
#  {'restarts': 186, 'conflicts': 233, 'decisions': 0, 'propagations': 1971},
#  {'restarts': 187, 'conflicts': 234, 'decisions': 0, 'propagations': 1982},
#  {'restarts': 188, 'conflicts': 235, 'decisions': 0, 'propagations': 1991},
#  {'restarts': 189, 'conflicts': 236, 'decisions': 0, 'propagations': 2002},
#  {'restarts': 190, 'conflicts': 237, 'decisions': 0, 'propagations': 2012},
#  {'restarts': 191, 'conflicts': 238, 'decisions': 0, 'propagations': 2022},
#  {'restarts': 192, 'conflicts': 241, 'decisions': 0, 'propagations': 2036},
#  {'restarts': 193, 'conflicts': 242, 'decisions': 0, 'propagations': 2044},
#  {'restarts': 194, 'conflicts': 243, 'decisions': 0, 'propagations': 2054},
#  {'restarts': 195, 'conflicts': 245, 'decisions': 0, 'propagations': 2065},
#  {'restarts': 196, 'conflicts': 246, 'decisions': 0, 'propagations': 2077},
#  {'restarts': 197, 'conflicts': 248, 'decisions': 0, 'propagations': 2090},
#  {'restarts': 198, 'conflicts': 249, 'decisions': 0, 'propagations': 2100},
#  {'restarts': 199, 'conflicts': 250, 'decisions': 0, 'propagations': 2109},
#  {'restarts': 200, 'conflicts': 251, 'decisions': 0, 'propagations': 2118},
#  {'restarts': 201, 'conflicts': 252, 'decisions': 0, 'propagations': 2129},
#  {'restarts': 202, 'conflicts': 255, 'decisions': 0, 'propagations': 2141},
#  {'restarts': 203, 'conflicts': 257, 'decisions': 0, 'propagations': 2152},
#  {'restarts': 204, 'conflicts': 257, 'decisions': 0, 'propagations': 2158},
#  {'restarts': 205, 'conflicts': 259, 'decisions': 0, 'propagations': 2170},
#  {'restarts': 206, 'conflicts': 261, 'decisions': 0, 'propagations': 2181},
#  {'restarts': 207, 'conflicts': 262, 'decisions': 0, 'propagations': 2191},
#  {'restarts': 208, 'conflicts': 263, 'decisions': 0, 'propagations': 2203},
#  {'restarts': 209, 'conflicts': 264, 'decisions': 0, 'propagations': 2212},
#  {'restarts': 210, 'conflicts': 265, 'decisions': 0, 'propagations': 2223},
#  {'restarts': 211, 'conflicts': 266, 'decisions': 0, 'propagations': 2233},
#  {'restarts': 212, 'conflicts': 267, 'decisions': 0, 'propagations': 2243},
#  {'restarts': 213, 'conflicts': 268, 'decisions': 0, 'propagations': 2254},
#  {'restarts': 214, 'conflicts': 269, 'decisions': 0, 'propagations': 2264},
#  {'restarts': 215, 'conflicts': 270, 'decisions': 0, 'propagations': 2276},
#  {'restarts': 216, 'conflicts': 271, 'decisions': 0, 'propagations': 2287},
#  {'restarts': 217, 'conflicts': 272, 'decisions': 0, 'propagations': 2299},
#  {'restarts': 218, 'conflicts': 273, 'decisions': 0, 'propagations': 2310},
#  {'restarts': 219, 'conflicts': 275, 'decisions': 0, 'propagations': 2323},
#  {'restarts': 220, 'conflicts': 277, 'decisions': 0, 'propagations': 2335},
#  {'restarts': 221, 'conflicts': 278, 'decisions': 0, 'propagations': 2345},
#  {'restarts': 222, 'conflicts': 279, 'decisions': 0, 'propagations': 2355},
#  {'restarts': 223, 'conflicts': 279, 'decisions': 0, 'propagations': 2364},
#  {'restarts': 224, 'conflicts': 280, 'decisions': 0, 'propagations': 2374},
#  {'restarts': 225, 'conflicts': 281, 'decisions': 0, 'propagations': 2383},
#  {'restarts': 226, 'conflicts': 282, 'decisions': 0, 'propagations': 2393},
#  {'restarts': 227, 'conflicts': 283, 'decisions': 0, 'propagations': 2402},
#  {'restarts': 228, 'conflicts': 285, 'decisions': 0, 'propagations': 2414},
#  {'restarts': 229, 'conflicts': 286, 'decisions': 0, 'propagations': 2426},
#  {'restarts': 230, 'conflicts': 288, 'decisions': 0, 'propagations': 2437},
#  {'restarts': 231, 'conflicts': 289, 'decisions': 0, 'propagations': 2448},
#  {'restarts': 232, 'conflicts': 289, 'decisions': 0, 'propagations': 2456},
#  {'restarts': 233, 'conflicts': 290, 'decisions': 0, 'propagations': 2465},
#  {'restarts': 234, 'conflicts': 293, 'decisions': 0, 'propagations': 2477},
#  {'restarts': 235, 'conflicts': 294, 'decisions': 0, 'propagations': 2489},
#  {'restarts': 236, 'conflicts': 295, 'decisions': 0, 'propagations': 2500},
#  {'restarts': 237, 'conflicts': 296, 'decisions': 0, 'propagations': 2510},
#  {'restarts': 238, 'conflicts': 297, 'decisions': 0, 'propagations': 2520},
#  {'restarts': 239, 'conflicts': 298, 'decisions': 0, 'propagations': 2531},
#  {'restarts': 240, 'conflicts': 299, 'decisions': 0, 'propagations': 2542},
#  {'restarts': 241, 'conflicts': 300, 'decisions': 0, 'propagations': 2552},
#  {'restarts': 242, 'conflicts': 301, 'decisions': 0, 'propagations': 2562},
#  {'restarts': 243, 'conflicts': 302, 'decisions': 0, 'propagations': 2572},
#  {'restarts': 244, 'conflicts': 302, 'decisions': 0, 'propagations': 2582},
#  {'restarts': 245, 'conflicts': 303, 'decisions': 0, 'propagations': 2592},
#  {'restarts': 246, 'conflicts': 304, 'decisions': 0, 'propagations': 2601},
#  {'restarts': 247, 'conflicts': 305, 'decisions': 0, 'propagations': 2610},
#  {'restarts': 248, 'conflicts': 305, 'decisions': 0, 'propagations': 2620},
#  {'restarts': 249, 'conflicts': 307, 'decisions': 0, 'propagations': 2633},
#  {'restarts': 250, 'conflicts': 308, 'decisions': 0, 'propagations': 2644},
#  {'restarts': 251, 'conflicts': 310, 'decisions': 0, 'propagations': 2656},
#  {'restarts': 252, 'conflicts': 311, 'decisions': 0, 'propagations': 2666},
#  {'restarts': 253, 'conflicts': 312, 'decisions': 0, 'propagations': 2677},
#  {'restarts': 254, 'conflicts': 313, 'decisions': 0, 'propagations': 2687},
#  {'restarts': 255, 'conflicts': 314, 'decisions': 0, 'propagations': 2696},
#  {'restarts': 256, 'conflicts': 315, 'decisions': 0, 'propagations': 2706},
#  {'restarts': 257, 'conflicts': 316, 'decisions': 0, 'propagations': 2715},
#  {'restarts': 258, 'conflicts': 317, 'decisions': 0, 'propagations': 2725},
#  {'restarts': 259, 'conflicts': 318, 'decisions': 0, 'propagations': 2736},
#  {'restarts': 260, 'conflicts': 319, 'decisions': 0, 'propagations': 2746},
#  {'restarts': 261, 'conflicts': 320, 'decisions': 0, 'propagations': 2756},
#  {'restarts': 262, 'conflicts': 321, 'decisions': 0, 'propagations': 2767},
#  {'restarts': 263, 'conflicts': 322, 'decisions': 0, 'propagations': 2777},
#  {'restarts': 264, 'conflicts': 324, 'decisions': 0, 'propagations': 2788},
#  {'restarts': 265, 'conflicts': 325, 'decisions': 0, 'propagations': 2799},
#  {'restarts': 266, 'conflicts': 326, 'decisions': 0, 'propagations': 2808},
#  {'restarts': 267, 'conflicts': 327, 'decisions': 0, 'propagations': 2817},
#  {'restarts': 268, 'conflicts': 329, 'decisions': 0, 'propagations': 2828},
#  {'restarts': 269, 'conflicts': 330, 'decisions': 0, 'propagations': 2838},
#  {'restarts': 270, 'conflicts': 331, 'decisions': 0, 'propagations': 2849},
#  {'restarts': 271, 'conflicts': 333, 'decisions': 0, 'propagations': 2861},
#  {'restarts': 272, 'conflicts': 335, 'decisions': 0, 'propagations': 2873},
#  {'restarts': 273, 'conflicts': 337, 'decisions': 0, 'propagations': 2884},
#  {'restarts': 274, 'conflicts': 338, 'decisions': 0, 'propagations': 2894},
#  {'restarts': 275, 'conflicts': 338, 'decisions': 0, 'propagations': 2903},
#  {'restarts': 276, 'conflicts': 340, 'decisions': 0, 'propagations': 2915},
#  {'restarts': 277, 'conflicts': 341, 'decisions': 0, 'propagations': 2925},
#  {'restarts': 278, 'conflicts': 342, 'decisions': 0, 'propagations': 2935},
#  {'restarts': 279, 'conflicts': 345, 'decisions': 0, 'propagations': 2948},
#  {'restarts': 280, 'conflicts': 346, 'decisions': 0, 'propagations': 2958},
#  {'restarts': 281, 'conflicts': 347, 'decisions': 0, 'propagations': 2969},
#  {'restarts': 282, 'conflicts': 349, 'decisions': 0, 'propagations': 2980},
#  {'restarts': 283, 'conflicts': 350, 'decisions': 0, 'propagations': 2988},
#  {'restarts': 284, 'conflicts': 351, 'decisions': 0, 'propagations': 2998},
#  {'restarts': 285, 'conflicts': 352, 'decisions': 0, 'propagations': 3009},
#  {'restarts': 286, 'conflicts': 353, 'decisions': 0, 'propagations': 3018},
#  {'restarts': 287, 'conflicts': 356, 'decisions': 0, 'propagations': 3030},
#  {'restarts': 288, 'conflicts': 358, 'decisions': 0, 'propagations': 3041},
#  {'restarts': 289, 'conflicts': 360, 'decisions': 0, 'propagations': 3054},
#  {'restarts': 290, 'conflicts': 361, 'decisions': 0, 'propagations': 3064},
#  {'restarts': 291, 'conflicts': 362, 'decisions': 0, 'propagations': 3075},
#  {'restarts': 292, 'conflicts': 362, 'decisions': 0, 'propagations': 3084},
#  {'restarts': 293, 'conflicts': 363, 'decisions': 0, 'propagations': 3094},
#  {'restarts': 294, 'conflicts': 365, 'decisions': 0, 'propagations': 3107},
#  {'restarts': 295, 'conflicts': 368, 'decisions': 0, 'propagations': 3122},
#  {'restarts': 296, 'conflicts': 369, 'decisions': 0, 'propagations': 3132},
#  {'restarts': 297, 'conflicts': 370, 'decisions': 0, 'propagations': 3141},
#  {'restarts': 298, 'conflicts': 371, 'decisions': 0, 'propagations': 3152},
#  {'restarts': 299, 'conflicts': 373, 'decisions': 0, 'propagations': 3164},
#  {'restarts': 300, 'conflicts': 374, 'decisions': 0, 'propagations': 3173},
#  {'restarts': 301, 'conflicts': 375, 'decisions': 0, 'propagations': 3184},
#  {'restarts': 302, 'conflicts': 376, 'decisions': 0, 'propagations': 3195},
#  {'restarts': 303, 'conflicts': 377, 'decisions': 0, 'propagations': 3207},
#  {'restarts': 304, 'conflicts': 378, 'decisions': 0, 'propagations': 3217},
#  {'restarts': 305, 'conflicts': 378, 'decisions': 0, 'propagations': 3227},
#  {'restarts': 306, 'conflicts': 380, 'decisions': 0, 'propagations': 3239},
#  {'restarts': 307, 'conflicts': 383, 'decisions': 0, 'propagations': 3252},
#  {'restarts': 308, 'conflicts': 384, 'decisions': 0, 'propagations': 3261},
#  {'restarts': 309, 'conflicts': 385, 'decisions': 0, 'propagations': 3272},
#  {'restarts': 310, 'conflicts': 386, 'decisions': 0, 'propagations': 3282},
#  {'restarts': 311, 'conflicts': 387, 'decisions': 0, 'propagations': 3292},
#  {'restarts': 312, 'conflicts': 388, 'decisions': 0, 'propagations': 3302},
#  {'restarts': 313, 'conflicts': 390, 'decisions': 0, 'propagations': 3317},
#  {'restarts': 314, 'conflicts': 391, 'decisions': 0, 'propagations': 3327},
#  {'restarts': 315, 'conflicts': 392, 'decisions': 0, 'propagations': 3337},
#  {'restarts': 316, 'conflicts': 393, 'decisions': 0, 'propagations': 3346},
#  {'restarts': 317, 'conflicts': 395, 'decisions': 0, 'propagations': 3359},
#  {'restarts': 318, 'conflicts': 397, 'decisions': 0, 'propagations': 3371},
#  {'restarts': 319, 'conflicts': 399, 'decisions': 0, 'propagations': 3384},
#  {'restarts': 320, 'conflicts': 401, 'decisions': 0, 'propagations': 3397},
#  {'restarts': 321, 'conflicts': 402, 'decisions': 0, 'propagations': 3407},
#  {'restarts': 322, 'conflicts': 402, 'decisions': 0, 'propagations': 3416},
#  {'restarts': 323, 'conflicts': 403, 'decisions': 0, 'propagations': 3427},
#  {'restarts': 324, 'conflicts': 405, 'decisions': 0, 'propagations': 3440},
#  {'restarts': 325, 'conflicts': 406, 'decisions': 0, 'propagations': 3450},
#  {'restarts': 326, 'conflicts': 407, 'decisions': 0, 'propagations': 3460},
#  {'restarts': 327, 'conflicts': 408, 'decisions': 0, 'propagations': 3472},
#  {'restarts': 328, 'conflicts': 409, 'decisions': 0, 'propagations': 3481},
#  {'restarts': 329, 'conflicts': 410, 'decisions': 0, 'propagations': 3490},
#  {'restarts': 330, 'conflicts': 411, 'decisions': 0, 'propagations': 3501},
#  {'restarts': 331, 'conflicts': 412, 'decisions': 0, 'propagations': 3511},
#  {'restarts': 332, 'conflicts': 413, 'decisions': 0, 'propagations': 3521},
#  {'restarts': 333, 'conflicts': 415, 'decisions': 0, 'propagations': 3532},
#  {'restarts': 334, 'conflicts': 416, 'decisions': 0, 'propagations': 3543},
#  {'restarts': 335, 'conflicts': 417, 'decisions': 0, 'propagations': 3552},
#  {'restarts': 336, 'conflicts': 418, 'decisions': 0, 'propagations': 3561},
#  {'restarts': 337, 'conflicts': 419, 'decisions': 0, 'propagations': 3571},
#  {'restarts': 338, 'conflicts': 420, 'decisions': 0, 'propagations': 3582},
#  {'restarts': 339, 'conflicts': 422, 'decisions': 0, 'propagations': 3594},
#  {'restarts': 340, 'conflicts': 424, 'decisions': 0, 'propagations': 3607},
#  {'restarts': 341, 'conflicts': 425, 'decisions': 0, 'propagations': 3615},
#  {'restarts': 342, 'conflicts': 427, 'decisions': 0, 'propagations': 3628},
#  {'restarts': 343, 'conflicts': 429, 'decisions': 0, 'propagations': 3640},
#  {'restarts': 344, 'conflicts': 429, 'decisions': 0, 'propagations': 3649},
#  {'restarts': 345, 'conflicts': 431, 'decisions': 0, 'propagations': 3662},
#  {'restarts': 346, 'conflicts': 432, 'decisions': 0, 'propagations': 3672},
#  {'restarts': 347, 'conflicts': 433, 'decisions': 0, 'propagations': 3682},
#  {'restarts': 348, 'conflicts': 434, 'decisions': 0, 'propagations': 3692},
#  {'restarts': 349, 'conflicts': 434, 'decisions': 0, 'propagations': 3702},
#  {'restarts': 350, 'conflicts': 436, 'decisions': 0, 'propagations': 3714},
#  {'restarts': 351, 'conflicts': 436, 'decisions': 0, 'propagations': 3722},
#  {'restarts': 352, 'conflicts': 438, 'decisions': 0, 'propagations': 3733},
#  {'restarts': 353, 'conflicts': 439, 'decisions': 0, 'propagations': 3743},
#  {'restarts': 354, 'conflicts': 440, 'decisions': 0, 'propagations': 3755},
#  {'restarts': 355, 'conflicts': 441, 'decisions': 0, 'propagations': 3764},
#  {'restarts': 356, 'conflicts': 443, 'decisions': 0, 'propagations': 3776},
#  {'restarts': 357, 'conflicts': 444, 'decisions': 0, 'propagations': 3786},
#  {'restarts': 358, 'conflicts': 445, 'decisions': 0, 'propagations': 3797},
#  {'restarts': 359, 'conflicts': 446, 'decisions': 0, 'propagations': 3807},
#  {'restarts': 360, 'conflicts': 446, 'decisions': 0, 'propagations': 3815},
#  {'restarts': 361, 'conflicts': 447, 'decisions': 0, 'propagations': 3826},
#  {'restarts': 362, 'conflicts': 449, 'decisions': 0, 'propagations': 3839},
#  {'restarts': 363, 'conflicts': 450, 'decisions': 0, 'propagations': 3849},
#  {'restarts': 364, 'conflicts': 451, 'decisions': 0, 'propagations': 3860},
#  {'restarts': 365, 'conflicts': 451, 'decisions': 0, 'propagations': 3868},
#  {'restarts': 366, 'conflicts': 453, 'decisions': 0, 'propagations': 3880},
#  {'restarts': 367, 'conflicts': 454, 'decisions': 0, 'propagations': 3889},
#  {'restarts': 368, 'conflicts': 456, 'decisions': 0, 'propagations': 3902},
#  {'restarts': 369, 'conflicts': 458, 'decisions': 0, 'propagations': 3915},
#  {'restarts': 370, 'conflicts': 459, 'decisions': 0, 'propagations': 3924},
#  {'restarts': 371, 'conflicts': 460, 'decisions': 0, 'propagations': 3934},
#  {'restarts': 372, 'conflicts': 461, 'decisions': 0, 'propagations': 3944},
#  {'restarts': 373, 'conflicts': 463, 'decisions': 0, 'propagations': 3956},
#  {'restarts': 374, 'conflicts': 464, 'decisions': 0, 'propagations': 3966},
#  {'restarts': 375, 'conflicts': 465, 'decisions': 0, 'propagations': 3977},
#  {'restarts': 376, 'conflicts': 466, 'decisions': 0, 'propagations': 3987},
#  {'restarts': 377, 'conflicts': 466, 'decisions': 0, 'propagations': 3996},
#  {'restarts': 378, 'conflicts': 468, 'decisions': 0, 'propagations': 4008},
#  {'restarts': 379, 'conflicts': 469, 'decisions': 0, 'propagations': 4017},
#  {'restarts': 380, 'conflicts': 471, 'decisions': 0, 'propagations': 4029},
#  {'restarts': 381, 'conflicts': 472, 'decisions': 0, 'propagations': 4039},
#  {'restarts': 382, 'conflicts': 473, 'decisions': 0, 'propagations': 4049},
#  {'restarts': 383, 'conflicts': 474, 'decisions': 0, 'propagations': 4058},
#  {'restarts': 384, 'conflicts': 475, 'decisions': 0, 'propagations': 4068},
#  {'restarts': 385, 'conflicts': 476, 'decisions': 0, 'propagations': 4078},
#  {'restarts': 386, 'conflicts': 477, 'decisions': 0, 'propagations': 4087},
#  {'restarts': 387, 'conflicts': 477, 'decisions': 0, 'propagations': 4095},
#  {'restarts': 388, 'conflicts': 478, 'decisions': 0, 'propagations': 4105},
#  {'restarts': 389, 'conflicts': 479, 'decisions': 0, 'propagations': 4115},
#  {'restarts': 390, 'conflicts': 480, 'decisions': 0, 'propagations': 4125},
#  {'restarts': 391, 'conflicts': 481, 'decisions': 0, 'propagations': 4135},
#  {'restarts': 392, 'conflicts': 483, 'decisions': 0, 'propagations': 4148},
#  {'restarts': 393, 'conflicts': 484, 'decisions': 0, 'propagations': 4159},
#  {'restarts': 394, 'conflicts': 486, 'decisions': 0, 'propagations': 4171},
#  {'restarts': 395, 'conflicts': 486, 'decisions': 0, 'propagations': 4180},
#  {'restarts': 396, 'conflicts': 486, 'decisions': 0, 'propagations': 4190},
#  {'restarts': 397, 'conflicts': 488, 'decisions': 0, 'propagations': 4201},
#  {'restarts': 398, 'conflicts': 490, 'decisions': 0, 'propagations': 4213},
#  {'restarts': 399, 'conflicts': 491, 'decisions': 0, 'propagations': 4223},
#  {'restarts': 400, 'conflicts': 492, 'decisions': 0, 'propagations': 4233},
#  {'restarts': 401, 'conflicts': 493, 'decisions': 0, 'propagations': 4243},
#  {'restarts': 402, 'conflicts': 494, 'decisions': 0, 'propagations': 4252},
#  {'restarts': 403, 'conflicts': 495, 'decisions': 0, 'propagations': 4263},
#  {'restarts': 404, 'conflicts': 497, 'decisions': 0, 'propagations': 4275},
#  {'restarts': 405, 'conflicts': 498, 'decisions': 0, 'propagations': 4284},
#  {'restarts': 406, 'conflicts': 499, 'decisions': 0, 'propagations': 4294},
#  {'restarts': 407, 'conflicts': 499, 'decisions': 0, 'propagations': 4304},
#  {'restarts': 408, 'conflicts': 499, 'decisions': 0, 'propagations': 4313},
#  {'restarts': 409, 'conflicts': 500, 'decisions': 0, 'propagations': 4324},
#  {'restarts': 410, 'conflicts': 501, 'decisions': 0, 'propagations': 4335},
#  {'restarts': 411, 'conflicts': 503, 'decisions': 0, 'propagations': 4346},
#  {'restarts': 412, 'conflicts': 503, 'decisions': 0, 'propagations': 4355},
#  {'restarts': 413, 'conflicts': 504, 'decisions': 0, 'propagations': 4364},
#  {'restarts': 414, 'conflicts': 505, 'decisions': 0, 'propagations': 4375},
#  {'restarts': 415, 'conflicts': 506, 'decisions': 0, 'propagations': 4385},
#  {'restarts': 416, 'conflicts': 507, 'decisions': 0, 'propagations': 4395},
#  {'restarts': 417, 'conflicts': 508, 'decisions': 0, 'propagations': 4405},
#  {'restarts': 418, 'conflicts': 509, 'decisions': 0, 'propagations': 4416},
#  {'restarts': 419, 'conflicts': 511, 'decisions': 0, 'propagations': 4428},
#  {'restarts': 420, 'conflicts': 512, 'decisions': 0, 'propagations': 4438},
#  {'restarts': 421, 'conflicts': 513, 'decisions': 0, 'propagations': 4448},
#  {'restarts': 422, 'conflicts': 513, 'decisions': 0, 'propagations': 4457},
#  {'restarts': 423, 'conflicts': 515, 'decisions': 0, 'propagations': 4468},
#  {'restarts': 424, 'conflicts': 515, 'decisions': 0, 'propagations': 4477},
#  {'restarts': 425, 'conflicts': 516, 'decisions': 0, 'propagations': 4486},
#  {'restarts': 426, 'conflicts': 517, 'decisions': 0, 'propagations': 4497},
#  {'restarts': 427, 'conflicts': 518, 'decisions': 0, 'propagations': 4507},
#  {'restarts': 428, 'conflicts': 520, 'decisions': 0, 'propagations': 4519},
#  {'restarts': 429, 'conflicts': 522, 'decisions': 0, 'propagations': 4531},
#  {'restarts': 430, 'conflicts': 522, 'decisions': 0, 'propagations': 4538},
#  {'restarts': 431, 'conflicts': 523, 'decisions': 0, 'propagations': 4548},
#  {'restarts': 432, 'conflicts': 526, 'decisions': 0, 'propagations': 4560},
#  {'restarts': 433, 'conflicts': 527, 'decisions': 0, 'propagations': 4570},
#  {'restarts': 434, 'conflicts': 528, 'decisions': 0, 'propagations': 4579},
#  {'restarts': 435, 'conflicts': 529, 'decisions': 0, 'propagations': 4589},
#  {'restarts': 436, 'conflicts': 531, 'decisions': 0, 'propagations': 4601},
#  {'restarts': 437, 'conflicts': 532, 'decisions': 0, 'propagations': 4612},
#  {'restarts': 438, 'conflicts': 533, 'decisions': 0, 'propagations': 4622},
#  {'restarts': 439, 'conflicts': 534, 'decisions': 0, 'propagations': 4633},
#  {'restarts': 440, 'conflicts': 535, 'decisions': 0, 'propagations': 4644},
#  {'restarts': 441, 'conflicts': 536, 'decisions': 0, 'propagations': 4655},
#  {'restarts': 442, 'conflicts': 537, 'decisions': 0, 'propagations': 4664},
#  {'restarts': 443, 'conflicts': 538, 'decisions': 0, 'propagations': 4675},
#  {'restarts': 444, 'conflicts': 539, 'decisions': 0, 'propagations': 4685},
#  {'restarts': 445, 'conflicts': 541, 'decisions': 0, 'propagations': 4697},
#  {'restarts': 446, 'conflicts': 542, 'decisions': 0, 'propagations': 4707},
#  {'restarts': 447, 'conflicts': 543, 'decisions': 0, 'propagations': 4716},
#  {'restarts': 448, 'conflicts': 544, 'decisions': 0, 'propagations': 4726},
#  {'restarts': 449, 'conflicts': 545, 'decisions': 0, 'propagations': 4736},
#  {'restarts': 450, 'conflicts': 546, 'decisions': 0, 'propagations': 4747},
#  {'restarts': 451, 'conflicts': 547, 'decisions': 0, 'propagations': 4757},
#  {'restarts': 452, 'conflicts': 547, 'decisions': 0, 'propagations': 4765},
#  {'restarts': 453, 'conflicts': 548, 'decisions': 0, 'propagations': 4775},
#  {'restarts': 454, 'conflicts': 550, 'decisions': 0, 'propagations': 4792},
#  {'restarts': 455, 'conflicts': 551, 'decisions': 0, 'propagations': 4802},
#  {'restarts': 456, 'conflicts': 551, 'decisions': 0, 'propagations': 4811},
#  {'restarts': 457, 'conflicts': 552, 'decisions': 0, 'propagations': 4818},
#  {'restarts': 458, 'conflicts': 553, 'decisions': 0, 'propagations': 4826},
#  {'restarts': 459, 'conflicts': 553, 'decisions': 0, 'propagations': 4836},
#  {'restarts': 460, 'conflicts': 554, 'decisions': 0, 'propagations': 4845},
#  {'restarts': 461, 'conflicts': 555, 'decisions': 0, 'propagations': 4855},
#  {'restarts': 462, 'conflicts': 556, 'decisions': 0, 'propagations': 4867},
#  {'restarts': 463, 'conflicts': 558, 'decisions': 0, 'propagations': 4877},
#  {'restarts': 464, 'conflicts': 558, 'decisions': 0, 'propagations': 4886},
#  {'restarts': 465, 'conflicts': 559, 'decisions': 0, 'propagations': 4897},
#  {'restarts': 466, 'conflicts': 559, 'decisions': 0, 'propagations': 4906},
#  {'restarts': 467, 'conflicts': 560, 'decisions': 0, 'propagations': 4916},
#  {'restarts': 468, 'conflicts': 561, 'decisions': 0, 'propagations': 4926},
#  {'restarts': 469, 'conflicts': 563, 'decisions': 0, 'propagations': 4937},
#  {'restarts': 470, 'conflicts': 564, 'decisions': 0, 'propagations': 4946},
#  {'restarts': 471, 'conflicts': 565, 'decisions': 0, 'propagations': 4955},
#  {'restarts': 472, 'conflicts': 566, 'decisions': 0, 'propagations': 4964},
#  {'restarts': 473, 'conflicts': 567, 'decisions': 0, 'propagations': 4974},
#  {'restarts': 474, 'conflicts': 568, 'decisions': 0, 'propagations': 4984},
#  {'restarts': 475, 'conflicts': 568, 'decisions': 0, 'propagations': 4994},
#  {'restarts': 476, 'conflicts': 568, 'decisions': 0, 'propagations': 5003},
#  {'restarts': 477, 'conflicts': 570, 'decisions': 0, 'propagations': 5016},
#  {'restarts': 478, 'conflicts': 571, 'decisions': 0, 'propagations': 5025},
#  {'restarts': 479, 'conflicts': 571, 'decisions': 0, 'propagations': 5032},
#  {'restarts': 480, 'conflicts': 572, 'decisions': 0, 'propagations': 5042},
#  {'restarts': 481, 'conflicts': 573, 'decisions': 0, 'propagations': 5053},
#  {'restarts': 482, 'conflicts': 574, 'decisions': 0, 'propagations': 5063},
#  {'restarts': 483, 'conflicts': 575, 'decisions': 0, 'propagations': 5073},
#  {'restarts': 484, 'conflicts': 576, 'decisions': 0, 'propagations': 5081},
#  {'restarts': 485, 'conflicts': 577, 'decisions': 0, 'propagations': 5090},
#  {'restarts': 486, 'conflicts': 578, 'decisions': 0, 'propagations': 5100},
#  {'restarts': 487, 'conflicts': 578, 'decisions': 0, 'propagations': 5111},
#  {'restarts': 488, 'conflicts': 580, 'decisions': 0, 'propagations': 5124},
#  {'restarts': 489, 'conflicts': 580, 'decisions': 0, 'propagations': 5133},
#  {'restarts': 490, 'conflicts': 581, 'decisions': 0, 'propagations': 5143},
#  {'restarts': 491, 'conflicts': 582, 'decisions': 0, 'propagations': 5154},
#  {'restarts': 492, 'conflicts': 584, 'decisions': 0, 'propagations': 5165},
#  {'restarts': 493, 'conflicts': 587, 'decisions': 0, 'propagations': 5180},
#  {'restarts': 494, 'conflicts': 588, 'decisions': 0, 'propagations': 5191},
#  {'restarts': 495, 'conflicts': 589, 'decisions': 0, 'propagations': 5200},
#  {'restarts': 496, 'conflicts': 590, 'decisions': 0, 'propagations': 5211},
#  {'restarts': 497, 'conflicts': 591, 'decisions': 0, 'propagations': 5221},
#  {'restarts': 498, 'conflicts': 592, 'decisions': 0, 'propagations': 5231},
#  {'restarts': 499, 'conflicts': 593, 'decisions': 0, 'propagations': 5243},
#  {'restarts': 500, 'conflicts': 594, 'decisions': 0, 'propagations': 5253},
#  {'restarts': 501, 'conflicts': 595, 'decisions': 0, 'propagations': 5263},
#  {'restarts': 502, 'conflicts': 597, 'decisions': 0, 'propagations': 5273},
#  {'restarts': 503, 'conflicts': 598, 'decisions': 0, 'propagations': 5283},
#  {'restarts': 504, 'conflicts': 599, 'decisions': 0, 'propagations': 5293},
#  {'restarts': 505, 'conflicts': 600, 'decisions': 0, 'propagations': 5304},
#  {'restarts': 506, 'conflicts': 601, 'decisions': 0, 'propagations': 5313},
#  {'restarts': 507, 'conflicts': 601, 'decisions': 0, 'propagations': 5321},
#  {'restarts': 508, 'conflicts': 602, 'decisions': 0, 'propagations': 5332},
#  {'restarts': 509, 'conflicts': 603, 'decisions': 0, 'propagations': 5342},
#  {'restarts': 510, 'conflicts': 604, 'decisions': 0, 'propagations': 5353},
#  {'restarts': 511, 'conflicts': 605, 'decisions': 0, 'propagations': 5365},
#  {'restarts': 512, 'conflicts': 606, 'decisions': 0, 'propagations': 5375},
#  {'restarts': 513, 'conflicts': 607, 'decisions': 0, 'propagations': 5384},
#  {'restarts': 514, 'conflicts': 608, 'decisions': 0, 'propagations': 5396},
#  {'restarts': 515, 'conflicts': 608, 'decisions': 0, 'propagations': 5406},
#  {'restarts': 516, 'conflicts': 608, 'decisions': 0, 'propagations': 5414},
#  {'restarts': 517, 'conflicts': 608, 'decisions': 0, 'propagations': 5426},
#  {'restarts': 518, 'conflicts': 609, 'decisions': 0, 'propagations': 5436},
#  {'restarts': 519, 'conflicts': 609, 'decisions': 0, 'propagations': 5445},
#  {'restarts': 520, 'conflicts': 613, 'decisions': 0, 'propagations': 5464},
#  {'restarts': 521, 'conflicts': 614, 'decisions': 0, 'propagations': 5475},
#  {'restarts': 522, 'conflicts': 616, 'decisions': 0, 'propagations': 5486},
#  {'restarts': 523, 'conflicts': 617, 'decisions': 0, 'propagations': 5497},
#  {'restarts': 524, 'conflicts': 617, 'decisions': 0, 'propagations': 5507},
#  {'restarts': 525, 'conflicts': 618, 'decisions': 0, 'propagations': 5516},
#  {'restarts': 526, 'conflicts': 619, 'decisions': 0, 'propagations': 5527},
#  {'restarts': 527, 'conflicts': 620, 'decisions': 0, 'propagations': 5538},
#  {'restarts': 528, 'conflicts': 620, 'decisions': 0, 'propagations': 5544},
#  {'restarts': 529, 'conflicts': 621, 'decisions': 0, 'propagations': 5555},
#  {'restarts': 530, 'conflicts': 622, 'decisions': 0, 'propagations': 5564},
#  {'restarts': 531, 'conflicts': 622, 'decisions': 0, 'propagations': 5572},
#  {'restarts': 532, 'conflicts': 622, 'decisions': 0, 'propagations': 5582},
#  {'restarts': 533, 'conflicts': 623, 'decisions': 0, 'propagations': 5593},
#  {'restarts': 534, 'conflicts': 624, 'decisions': 0, 'propagations': 5602},
#  {'restarts': 535, 'conflicts': 627, 'decisions': 0, 'propagations': 5619},
#  {'restarts': 536, 'conflicts': 629, 'decisions': 0, 'propagations': 5629},
#  {'restarts': 537, 'conflicts': 630, 'decisions': 0, 'propagations': 5639},
#  {'restarts': 538, 'conflicts': 631, 'decisions': 0, 'propagations': 5649},
#  {'restarts': 539, 'conflicts': 631, 'decisions': 0, 'propagations': 5658},
#  {'restarts': 540, 'conflicts': 633, 'decisions': 0, 'propagations': 5672},
#  {'restarts': 541, 'conflicts': 634, 'decisions': 0, 'propagations': 5682},
#  {'restarts': 542, 'conflicts': 636, 'decisions': 0, 'propagations': 5693},
#  {'restarts': 543, 'conflicts': 637, 'decisions': 0, 'propagations': 5703},
#  {'restarts': 544, 'conflicts': 639, 'decisions': 0, 'propagations': 5714},
#  {'restarts': 545, 'conflicts': 641, 'decisions': 0, 'propagations': 5725},
#  {'restarts': 546, 'conflicts': 643, 'decisions': 0, 'propagations': 5737},
#  {'restarts': 547, 'conflicts': 644, 'decisions': 0, 'propagations': 5745}]

# %%
len(stats)
# Out:
# 547
